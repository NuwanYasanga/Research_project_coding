# %%
import pandas as pd
import numpy as np
import os
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
# %matplotlib inline

# %%
data_dir = 'C:/Research Activities/Dataset/BB-MAS_Dataset/Desktop_features_fixed/'

all_users = pd.DataFrame()
user_files = os.listdir(data_dir)
for i in tqdm(range(len(user_files))):
        user_file = user_files[i]
        curr_user_ind = int(user_file[user_file.find('_')+1:user_file.find('.')])
        data_frame = pd.read_csv(data_dir+user_file, header=0)
        data_frame['User'] = curr_user_ind
        all_users = all_users.append(data_frame, ignore_index=True)
# Out:
#   0%|          | 0/115 [00:00<?, ?it/s]

# %%
distance_1 = all_users[all_users['Distance']==1]
distance_2 = all_users[all_users['Distance']==2]
distance_3 = all_users[all_users['Distance']==3]

# %%
distance_1_mean_f1 = distance_1.groupby(['User','Hands'])['F1'].mean().reset_index()
distance_1_mean_f1_RH = distance_1_mean_f1[distance_1_mean_f1['Hands']=='RR']
distance_1_mean_f1_LH = distance_1_mean_f1[distance_1_mean_f1['Hands']=='LL']

# %%
types = distance_1_mean_f1_RH.reset_index()['User'].values
y = distance_1_mean_f1_RH['F1'].values
x = distance_1_mean_f1_RH['User'].values
fig, ax = plt.subplots(figsize=(20,10))
for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='red')
    plt.xlabel("User")
    plt.ylabel("Mean_F1_Right_Hand")
plt.grid(axis='y')
plt.show()

# %%
types = distance_1_mean_f1_LH.reset_index()['User'].values
y = distance_1_mean_f1_LH['F1'].values
x = distance_1_mean_f1_LH['User'].values
fig, ax = plt.subplots(figsize=(20,10))
for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='blue')
    plt.xlabel("User")
    plt.ylabel("Mean_F1_Left_Hand")
plt.grid(axis='y')
plt.show()

# %%
distance_1_std_f1 = distance_1.groupby(['User','Hands'])['F1'].std().reset_index()
distance_1_std_f1_RH = distance_1_std_f1[distance_1_std_f1['Hands']=='RR']
distance_1_std_f1_LH = distance_1_std_f1[distance_1_std_f1['Hands']=='LL']

# %%
types = distance_1_std_f1_RH.reset_index()['User'].values
y = distance_1_std_f1_RH['F1'].values
x = distance_1_std_f1_RH['User'].values
fig, ax = plt.subplots(figsize=(20,10))
for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='orange')
plt.grid(axis='y')
plt.show()

# %%
types = distance_1_std_f1_LH.reset_index()['User'].values
y = distance_1_std_f1_LH['F1'].values
x = distance_1_std_f1_LH['User'].values
fig, ax = plt.subplots(figsize=(20,10))
for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='purple')
plt.grid(axis='y')
plt.show()

# %%
list_of_Users = [1,20,33,44,83, 114]
user_subset_less_200 = all_users[(all_users['User'].isin(list_of_Users)) & (all_users['Hands']=='LL')]

# %%
user_subset_less_200['User'].unique()
# Out:
# array([  1, 114,  20,  33,  44,  83], dtype=int64)

# %%
plt.figure(figsize=(15,8))
sns.stripplot(x=user_subset_less_200['User'], y=user_subset_less_200['F1'], data=user_subset_less_200)
plt.show()

# %%
list_of_Users = [11,36,67,93,108,116]
user_subset_more_700 = all_users[(all_users['User'].isin(list_of_Users)) & (all_users['Hands']=='RR')]

# %%
plt.figure(figsize=(15,8))
sns.stripplot(x=user_subset_more_700['User'], y=user_subset_more_700['F1'], data=user_subset_more_700)
plt.show()

# %%
list_of_Users = [2,27,32,39,64,74,101]
user_subset_more_200 = all_users[(all_users['User'].isin(list_of_Users)) & (all_users['Hands']=='RR')]

# %%
plt.figure(figsize=(15,8))
sns.stripplot(x=user_subset_more_200['User'], y=user_subset_more_200['F1'], data=user_subset_more_200)
plt.show()

# %%
distance_2_mean_f1 = distance_2.groupby(['User','Hands'])['F1'].mean().reset_index()
distance_2_mean_f1_RH = distance_2_mean_f1[distance_2_mean_f1['Hands']=='RR']
distance_2_mean_f1_LH = distance_2_mean_f1[distance_2_mean_f1['Hands']=='LL']

# %%
types = distance_2_mean_f1_RH.reset_index()['User'].values
y = distance_2_mean_f1_RH['F1'].values
x = distance_2_mean_f1_RH['User'].values
fig, ax = plt.subplots(figsize=(20,10))
for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='red')
plt.grid(axis='y')
plt.show()

# %%
types = distance_2_mean_f1_LH.reset_index()['User'].values
y = distance_2_mean_f1_LH['F1'].values
x = distance_2_mean_f1_LH['User'].values
fig, ax = plt.subplots(figsize=(20,10))
for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='blue')
plt.grid(axis='y')
plt.show()

# %%
distance_2_std_f1 = distance_2.groupby(['User','Hands'])['F1'].std().reset_index()
distance_2_std_f1_RH = distance_2_std_f1[distance_2_std_f1['Hands']=='RR']
distance_2_std_f1_LH = distance_2_std_f1[distance_2_std_f1['Hands']=='LL']

# %%
types = distance_2_std_f1_RH.reset_index()['User'].values
y = distance_2_std_f1_RH['F1'].values
x = distance_2_std_f1_RH['User'].values
fig, ax = plt.subplots(figsize=(20,10))
for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='orange')
plt.grid(axis='y')
plt.show()

# %%
types = distance_2_std_f1_LH.reset_index()['User'].values
y = distance_2_std_f1_LH['F1'].values
x = distance_2_std_f1_LH['User'].values
fig, ax = plt.subplots(figsize=(20,10))
for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='purple')
plt.grid(axis='y')
plt.show()

# %%
types = distance_2_mean_f1_RH.reset_index()['User'].values
y = distance_2_mean_f1_RH['F1'].values
x = distance_1_mean_f1_RH['F1'].values
fig, ax = plt.subplots(figsize=(20,10))
for i, txt in enumerate(types):
    ax.annotate(txt, (x[i], y[i]), xytext=(10,10), textcoords='offset points')
    plt.scatter(x, y, marker='x', color='black')
    plt.xlabel("Distance 1 mean_F1")
    plt.ylabel("Distance 2 mean_F1")
#plt.grid(axis='y')
plt.show()
